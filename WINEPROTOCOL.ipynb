# %%
import csv
import pandas as pd
from fuzzywuzzy import fuzz
from fuzzywuzzy import process 
# %run DocumentCleaner.ipynb
similarity_threshold = 80

WJAN1 = DocClean("AVTWINEJAN1.csv")

for i in WJAN1["Product Name"]:
    for j in WJAN1["Product Name"]:
        if fuzz.ratio(str(i), str(j)) > 90:
            print(str(i),str(j))
# Out:
# nan nan
# nan nan
# nan nan
# WINE VILLA MARCHESI PROSECCO WINE VILLA MARCHESI PROSECCO
# WINE VILLA MARCHESI PROSECCO WINE VILLA MARCHESI PROSECCO ROSE
# WINE KEG FAMILLE PERRIN RASCAL RED WINE KEG FAMILLE PERRIN RASCAL RED
# WINE KEG FAMILLE PERRIN RASCAL RED WINE BTL FAMILLE PERRIN RASCAL RED
# WINE KEG FAMILLE PERRIN RASCAL RED WINE KEG FAMILLE PERRIN RASCAL WHITE
# WINE SCARPETTA FRICO FRIULI VENEZIA GIULIA PINOT GRIGIO WINE SCARPETTA FRICO FRIULI VENEZIA GIULIA PINOT GRIGIO
# WINE SUNDOWNER CHARDONNAY BTLS WINE SUNDOWNER CHARDONNAY BTLS
# WINE VEUVE CLIQUOT WINE VEUVE CLIQUOT
# WINE BTL FAMILLE PERRIN RASCAL RED WINE KEG FAMILLE PERRIN RASCAL RED
# WINE BTL FAMILLE PERRIN RASCAL RED WINE BTL FAMILLE PERRIN RASCAL RED
# WINE BTL FAMILLE PERRIN RASCAL RED WINE BTL FAMILLE PERRIN RASCAL WHITE
# WINE KEG LA VIEILLE FERME ROSE WINE KEG LA VIEILLE FERME ROSE
# WINE SANCERRE HUBERT BROCHARD CLASSIC WINE SANCERRE HUBERT BROCHARD CLASSIC
# ...
