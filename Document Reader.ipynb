# %%
import csv
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import matplotlib as mpl
from fuzzywuzzy import fuzz
from fuzzywuzzy import process 

pd.set_option('display.max_rows', None)
# %run DocumentCleaner.ipynb


BDATA = DocClean("BeerYear2023.csv")
WDATA = DocClean("WineYear2023.csv")
LDATA = DocClean("LiquorYear2023.csv")
beer = BDATA["Product Name"].tolist()
BDATA['Variance'] = BDATA['Variance'].str.replace(',', '').astype(float)

ax = BDATA.plot.bar(x ="Product Name", y = "Variance", rot = 0)
ypos = np.arange(5)
xpos = [BDATA["Variance"]]
plt.xticks(ypos, BDATA["Product Name"].head())
plt.ylabel("COGS")
plt.title("Variance of Beer Products")
plt.bar(ypos, xpos)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 25
#      23 plt.ylabel("COGS")
#      24 plt.title("Variance of Beer Products")
# ---> 25 plt.bar(ypos, xpos)
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/pyplot.py:2739, in bar(x, height, width, bottom, align, data, **kwargs)
#    2728 @_copy_docstring_and_deprecators(Axes.bar)
#    2729 def bar(
#    2730     x: float | ArrayLike,
#    (...)
#    2737     **kwargs,
#    2738 ) -> BarContainer:
# -> 2739     return gca().bar(
#    2740         x,
#    2741         height,
#    2742         width=width,
#    2743         bottom=bottom,
#    2744         align=align,
#    2745         **({"data": data} if data is not None else {}),
#    2746         **kwargs,
#    2747     )
#
# ...
